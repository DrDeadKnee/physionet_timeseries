# %%
import numpy as np
import pandas as pd
import os
import random
import pyarrow
from tensorflow import keras
from sklearn.model_selection import train_test_split
#import sktime

# %%
pd.options.display.max_rows=999

# %%
raw_data_p = r'/h/dsmith/physionet_data/prepped/physionet_data.parquet'

# %%
df = pd.read_parquet(raw_data_p, engine='pyarrow')
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (1429854, 43)

# %%
df.head(5)
# Out:
#      HR  O2Sat    Temp    SBP    MAP   DBP  Resp      EtCO2  BaseExcess  \
# 0  60.0   98.0  36.200  135.0  109.0  72.0  17.0  33.017979   -0.441724
# 1  60.0   98.0  36.200  135.0  109.0  72.0  17.0  33.017979   -0.441724
# 2  56.0   98.0  36.225  127.0  105.0  73.0  15.0  33.017979   -0.441724
# 3  54.0   98.0  36.250  119.0  100.0  76.0  13.0  33.017979   -0.441724
# 4  52.0   98.0  36.275  119.0   87.0  67.0  12.0  33.017979   -0.441724
#
#         HCO3  ...  Platelets   Age  Gender     Unit1     Unit2  HospAdmTime  \
# 0  24.382587  ...      194.0  57.0     0.0  0.492043  0.507957       -12.02
# 1  24.382587  ...      194.0  57.0     0.0  0.492043  0.507957       -12.02
# 2  24.382587  ...      194.0  57.0     0.0  0.492043  0.507957       -12.02
# 3  24.382587  ...      194.0  57.0     0.0  0.492043  0.507957       -12.02
# 4  24.382587  ...      194.0  57.0     0.0  0.492043  0.507957       -12.02
#
#    ICULOS  SepsisLabel  SepsisEver     id
# 0     1.0          0.0           0  27338
# 1     2.0          0.0           0  27338
# 2     3.0          0.0           0  27338
# 3     4.0          0.0           0  27338
# 4     5.0          0.0           0  27338
#
# [5 rows x 43 columns]

# %%
df.id.nunique()
# Out:
# 36612

# %%
### check for non-static variables. Keep them for later steps
var_mtx = df.groupby('id').agg('var').reset_index(drop=True)
eps = 0
var_keep = list(var_mtx.columns[var_mtx.sum() > eps])

# %%
var_keep
# Out:
# ['HR',
#  'O2Sat',
#  'Temp',
#  'SBP',
#  'MAP',
#  'DBP',
#  'Resp',
#  'EtCO2',
#  'BaseExcess',
#  'HCO3',
#  'FiO2',
#  'pH',
#  'PaCO2',
#  'SaO2',
#  'AST',
#  'BUN',
#  'Alkalinephos',
#  'Calcium',
#  'Chloride',
#  'Creatinine',
#  'Bilirubin_direct',
#  'Glucose',
#  'Lactate',
#  'Magnesium',
#  'Phosphate',
#  'Potassium',
#  'Bilirubin_total',
#  'TroponinI',
#  'Hct',
#  'Hgb',
#  'PTT',
#  'WBC',
#  'Fibrinogen',
#  'Platelets',
#  'ICULOS',
#  'SepsisLabel']

# %% [markdown]
# Starter Model:
# 1. use min_len = min(time serires length for subject i, for i = 1,2,..., N) as unified length of input time series
# 2. keep the last min_len\$th\$ readings of each subject
# 3. include all non-static variables

# %%
#df.groupby('id').apply(lambda x:x.shape[0]).describe([x/10 for x in range(11)])
min_len = df.groupby('id').apply(lambda x:x.shape[0]).min()

# %%
print(min_len)
# Out:
# 11

# %%
#df.groupby('id').apply(lambda x:x.shape[0]).describe()

# %%
df_short = df.groupby('id').apply(lambda x:x.tail(min_len))
df_short = df_short.reset_index(drop=True)

# %%
df_short.head(20)
# Out:
#       HR  O2Sat       Temp     SBP    MAP   DBP  Resp      EtCO2  BaseExcess  \
# 0   89.0   99.0  38.280000  164.00  85.00  57.0  27.0  33.017979        -2.0
# 1   88.0   98.0  38.056667  147.00  77.00  51.0  24.0  33.017979        -2.0
# 2   84.5   99.0  37.833333  140.50  74.00  50.0  30.0  33.017979        -2.0
# 3   83.0   99.5  37.610000  133.50  70.00  49.0  28.0  33.017979        -2.0
# 4   88.0   99.0  37.644000   83.75  55.17  48.0  27.0  33.017979        -2.0
# 5   87.0   97.0  37.678000  130.00  67.33  54.0  28.0  33.017979        -1.8
# 6   90.0   97.0  37.712000  137.00  75.00  51.0  28.0  33.017979        -1.6
# 7   90.0   98.0  37.746000  148.50  83.25  55.5  26.0  33.017979        -1.4
# 8   90.0   99.0  37.780000  160.00  91.50  60.0  29.5  33.017979        -1.2
# 9   82.0   98.0  37.780000  129.00  66.00  43.0  25.0  33.017979        -1.0
# 10  84.0  100.0  37.780000  119.00  71.00  47.0  25.0  33.017979        -1.0
# 11  84.0   91.0  36.390000   93.00  60.00  44.0  17.0  33.017979        -2.0
# 12  82.0   96.0  36.491667   94.00  60.00  42.0  20.0  33.017979        -2.0
# 13  88.0   96.0  36.593333   96.00  62.00  44.0  21.0  33.017979        -2.0
# 14  78.0   96.0  36.695000   93.00  58.00  39.0  15.0  33.017979        -2.0
# 15  77.0   95.0  36.796667   89.00  56.00  39.0  17.0  33.017979        -2.0
# 16  86.0   95.5  36.898333  106.50  67.50  48.5  19.5  33.017979        -2.0
# 17  83.0   93.0  37.000000  103.00  66.00  47.0  21.0  33.017979        -2.0
# 18  80.0   92.0  37.000000   92.00  59.00  43.0  15.0  33.017979        -2.0
# 19  78.0   92.0  37.000000   96.00  62.00  46.0  16.0  33.017979        -2.0
#
#          HCO3  ...  Platelets    Age  Gender     Unit1     Unit2  HospAdmTime  \
# 0   18.608696  ...      197.0  63.18     0.0  0.492043  0.507957        -0.02
# 1   18.652174  ...      197.0  63.18     0.0  0.492043  0.507957        -0.02
# 2   18.695652  ...      197.0  63.18     0.0  0.492043  0.507957        -0.02
# 3   18.739130  ...      197.0  63.18     0.0  0.492043  0.507957        -0.02
# 4   18.782609  ...      197.0  63.18     0.0  0.492043  0.507957        -0.02
# 5   18.826087  ...      197.0  63.18     0.0  0.492043  0.507957        -0.02
# 6   18.869565  ...      197.0  63.18     0.0  0.492043  0.507957        -0.02
# 7   18.913043  ...      197.0  63.18     0.0  0.492043  0.507957        -0.02
# 8   18.956522  ...      197.0  63.18     0.0  0.492043  0.507957        -0.02
# 9   19.000000  ...      197.0  63.18     0.0  0.492043  0.507957        -0.02
# 10  19.000000  ...      197.0  63.18     0.0  0.492043  0.507957        -0.02
# 11  23.500000  ...      109.0  58.67     1.0  0.000000  1.000000       -72.06
# 12  23.250000  ...      109.0  58.67     1.0  0.000000  1.000000       -72.06
# 13  23.000000  ...      109.0  58.67     1.0  0.000000  1.000000       -72.06
# 14  23.000000  ...      109.0  58.67     1.0  0.000000  1.000000       -72.06
# 15  23.000000  ...      109.0  58.67     1.0  0.000000  1.000000       -72.06
# 16  23.000000  ...      109.0  58.67     1.0  0.000000  1.000000       -72.06
# 17  23.000000  ...      109.0  58.67     1.0  0.000000  1.000000       -72.06
# 18  23.000000  ...      109.0  58.67     1.0  0.000000  1.000000       -72.06
# 19  23.000000  ...      109.0  58.67     1.0  0.000000  1.000000       -72.06
#
#     ICULOS  SepsisLabel  SepsisEver   id
# 0     88.0          0.0         1.0  1.0
# 1     89.0          1.0         1.0  1.0
# 2     90.0          1.0         1.0  1.0
# 3     91.0          1.0         1.0  1.0
# 4     92.0          1.0         1.0  1.0
# 5     93.0          1.0         1.0  1.0
# 6     94.0          1.0         1.0  1.0
# 7     95.0          1.0         1.0  1.0
# 8     96.0          1.0         1.0  1.0
# 9     97.0          1.0         1.0  1.0
# 10    98.0          1.0         1.0  1.0
# 11    39.0          0.0         0.0  2.0
# 12    40.0          0.0         0.0  2.0
# 13    41.0          0.0         0.0  2.0
# 14    42.0          0.0         0.0  2.0
# 15    43.0          0.0         0.0  2.0
# 16    44.0          0.0         0.0  2.0
# 17    45.0          0.0         0.0  2.0
# 18    46.0          0.0         0.0  2.0
# 19    47.0          0.0         0.0  2.0
#
# [20 rows x 43 columns]

# %%
X = np.array(list(df_short.groupby('id').apply(lambda x:x[x_var].values.tolist())))
y = np.array(df_short.groupby('id').apply(lambda x: 1 if x['SepsisLabel'].sum()>=1 else 0))

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (27685, 11, 35)
# (27685,)
# (11866, 11, 35)
# (11866,)

# %%
x_train = x_train.reshape((x_train.shape[0], min_len, len(x_var)))
x_test = x_test.reshape((x_test.shape[0], min_len, len(x_var)))

# %%
num_classes = len(np.unique(y_train))

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# 693/693 [==============================] - 4s 5ms/step - loss: 0.1927 - sparse_categorical_accuracy: 0.9456 - val_loss: 0.2004 - val_sparse_categorical_accuracy: 0.9487 - lr: 0.0010
# Epoch 2/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1649 - sparse_categorical_accuracy: 0.9515 - val_loss: 0.1793 - val_sparse_categorical_accuracy: 0.9494 - lr: 0.0010
# Epoch 3/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1599 - sparse_categorical_accuracy: 0.9535 - val_loss: 0.1739 - val_sparse_categorical_accuracy: 0.9505 - lr: 0.0010
# Epoch 4/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1540 - sparse_categorical_accuracy: 0.9541 - val_loss: 0.1807 - val_sparse_categorical_accuracy: 0.9487 - lr: 0.0010
# Epoch 5/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1501 - sparse_categorical_accuracy: 0.9545 - val_loss: 0.1850 - val_sparse_categorical_accuracy: 0.9427 - lr: 0.0010
# Epoch 6/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1482 - sparse_categorical_accuracy: 0.9551 - val_loss: 0.1904 - val_sparse_categorical_accuracy: 0.9391 - lr: 0.0010
# Epoch 7/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1468 - sparse_categorical_accuracy: 0.9555 - val_loss: 0.1938 - val_sparse_categorical_accuracy: 0.9460 - lr: 0.0010
# Epoch 8/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1419 - sparse_categorical_accuracy: 0.9560 - val_loss: 0.1745 - val_sparse_categorical_accuracy: 0.9500 - lr: 0.0010
# Epoch 9/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1424 - sparse_categorical_accuracy: 0.9564 - val_loss: 0.1912 - val_sparse_categorical_accuracy: 0.9464 - lr: 0.0010
# Epoch 10/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1394 - sparse_categorical_accuracy: 0.9564 - val_loss: 0.1594 - val_sparse_categorical_accuracy: 0.9503 - lr: 0.0010
# Epoch 11/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1377 - sparse_categorical_accuracy: 0.9565 - val_loss: 0.1709 - val_sparse_categorical_accuracy: 0.9496 - lr: 0.0010
# Epoch 12/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1355 - sparse_categorical_accuracy: 0.9573 - val_loss: 0.2449 - val_sparse_categorical_accuracy: 0.9234 - lr: 0.0010
# Epoch 13/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1357 - sparse_categorical_accuracy: 0.9572 - val_loss: 0.1663 - val_sparse_categorical_accuracy: 0.9453 - lr: 0.0010
# Epoch 14/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1328 - sparse_categorical_accuracy: 0.9567 - val_loss: 0.1627 - val_sparse_categorical_accuracy: 0.9464 - lr: 0.0010
# Epoch 15/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1308 - sparse_categorical_accuracy: 0.9575 - val_loss: 0.1705 - val_sparse_categorical_accuracy: 0.9453 - lr: 0.0010
# Epoch 16/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1297 - sparse_categorical_accuracy: 0.9586 - val_loss: 0.1600 - val_sparse_categorical_accuracy: 0.9509 - lr: 0.0010
# Epoch 17/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1276 - sparse_categorical_accuracy: 0.9588 - val_loss: 0.1799 - val_sparse_categorical_accuracy: 0.9464 - lr: 0.0010
# Epoch 18/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1271 - sparse_categorical_accuracy: 0.9584 - val_loss: 0.2376 - val_sparse_categorical_accuracy: 0.9196 - lr: 0.0010
# Epoch 19/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1245 - sparse_categorical_accuracy: 0.9587 - val_loss: 0.2097 - val_sparse_categorical_accuracy: 0.9310 - lr: 0.0010
# Epoch 20/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1232 - sparse_categorical_accuracy: 0.9606 - val_loss: 0.2042 - val_sparse_categorical_accuracy: 0.9344 - lr: 0.0010
# Epoch 21/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1208 - sparse_categorical_accuracy: 0.9599 - val_loss: 0.1789 - val_sparse_categorical_accuracy: 0.9464 - lr: 0.0010
# Epoch 22/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1204 - sparse_categorical_accuracy: 0.9603 - val_loss: 0.1752 - val_sparse_categorical_accuracy: 0.9521 - lr: 0.0010
# Epoch 23/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1182 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.1616 - val_sparse_categorical_accuracy: 0.9496 - lr: 0.0010
# Epoch 24/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1165 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.1838 - val_sparse_categorical_accuracy: 0.9496 - lr: 0.0010
# Epoch 25/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1161 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.1759 - val_sparse_categorical_accuracy: 0.9413 - lr: 0.0010
# Epoch 26/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1158 - sparse_categorical_accuracy: 0.9612 - val_loss: 0.1945 - val_sparse_categorical_accuracy: 0.9400 - lr: 0.0010
# Epoch 27/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1121 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.1653 - val_sparse_categorical_accuracy: 0.9503 - lr: 0.0010
# Epoch 28/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1136 - sparse_categorical_accuracy: 0.9619 - val_loss: 0.1716 - val_sparse_categorical_accuracy: 0.9491 - lr: 0.0010
# Epoch 29/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1136 - sparse_categorical_accuracy: 0.9611 - val_loss: 0.1906 - val_sparse_categorical_accuracy: 0.9467 - lr: 0.0010
# Epoch 30/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1107 - sparse_categorical_accuracy: 0.9630 - val_loss: 0.1710 - val_sparse_categorical_accuracy: 0.9493 - lr: 0.0010
# Epoch 31/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.1008 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.1757 - val_sparse_categorical_accuracy: 0.9494 - lr: 5.0000e-04
# Epoch 32/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0999 - sparse_categorical_accuracy: 0.9665 - val_loss: 0.1801 - val_sparse_categorical_accuracy: 0.9503 - lr: 5.0000e-04
# Epoch 33/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0961 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.1814 - val_sparse_categorical_accuracy: 0.9473 - lr: 5.0000e-04
# Epoch 34/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0954 - sparse_categorical_accuracy: 0.9671 - val_loss: 0.1808 - val_sparse_categorical_accuracy: 0.9482 - lr: 5.0000e-04
# Epoch 35/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0946 - sparse_categorical_accuracy: 0.9673 - val_loss: 0.1901 - val_sparse_categorical_accuracy: 0.9427 - lr: 5.0000e-04
# Epoch 36/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0936 - sparse_categorical_accuracy: 0.9689 - val_loss: 0.1981 - val_sparse_categorical_accuracy: 0.9372 - lr: 5.0000e-04
# Epoch 37/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0942 - sparse_categorical_accuracy: 0.9676 - val_loss: 0.1857 - val_sparse_categorical_accuracy: 0.9453 - lr: 5.0000e-04
# Epoch 38/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0912 - sparse_categorical_accuracy: 0.9677 - val_loss: 0.1905 - val_sparse_categorical_accuracy: 0.9440 - lr: 5.0000e-04
# Epoch 39/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0910 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.1906 - val_sparse_categorical_accuracy: 0.9408 - lr: 5.0000e-04
# Epoch 40/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0887 - sparse_categorical_accuracy: 0.9707 - val_loss: 0.2299 - val_sparse_categorical_accuracy: 0.9493 - lr: 5.0000e-04
# Epoch 41/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0880 - sparse_categorical_accuracy: 0.9693 - val_loss: 0.2030 - val_sparse_categorical_accuracy: 0.9424 - lr: 5.0000e-04
# Epoch 42/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0881 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.1892 - val_sparse_categorical_accuracy: 0.9451 - lr: 5.0000e-04
# Epoch 43/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0867 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.1999 - val_sparse_categorical_accuracy: 0.9446 - lr: 5.0000e-04
# Epoch 44/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0853 - sparse_categorical_accuracy: 0.9699 - val_loss: 0.1958 - val_sparse_categorical_accuracy: 0.9406 - lr: 5.0000e-04
# Epoch 45/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0832 - sparse_categorical_accuracy: 0.9716 - val_loss: 0.2030 - val_sparse_categorical_accuracy: 0.9469 - lr: 5.0000e-04
# Epoch 46/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0847 - sparse_categorical_accuracy: 0.9701 - val_loss: 0.2012 - val_sparse_categorical_accuracy: 0.9485 - lr: 5.0000e-04
# Epoch 47/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0829 - sparse_categorical_accuracy: 0.9710 - val_loss: 0.2021 - val_sparse_categorical_accuracy: 0.9446 - lr: 5.0000e-04
# Epoch 48/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0836 - sparse_categorical_accuracy: 0.9707 - val_loss: 0.2234 - val_sparse_categorical_accuracy: 0.9426 - lr: 5.0000e-04
# Epoch 49/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0800 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.2092 - val_sparse_categorical_accuracy: 0.9364 - lr: 5.0000e-04
# Epoch 50/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0799 - sparse_categorical_accuracy: 0.9718 - val_loss: 0.2074 - val_sparse_categorical_accuracy: 0.9435 - lr: 5.0000e-04
# Epoch 51/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0709 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.2122 - val_sparse_categorical_accuracy: 0.9453 - lr: 2.5000e-04
# Epoch 52/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0708 - sparse_categorical_accuracy: 0.9749 - val_loss: 0.2133 - val_sparse_categorical_accuracy: 0.9447 - lr: 2.5000e-04
# Epoch 53/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0709 - sparse_categorical_accuracy: 0.9748 - val_loss: 0.2127 - val_sparse_categorical_accuracy: 0.9462 - lr: 2.5000e-04
# Epoch 54/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0688 - sparse_categorical_accuracy: 0.9758 - val_loss: 0.2147 - val_sparse_categorical_accuracy: 0.9464 - lr: 2.5000e-04
# Epoch 55/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0689 - sparse_categorical_accuracy: 0.9759 - val_loss: 0.2347 - val_sparse_categorical_accuracy: 0.9447 - lr: 2.5000e-04
# Epoch 56/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0664 - sparse_categorical_accuracy: 0.9761 - val_loss: 0.2209 - val_sparse_categorical_accuracy: 0.9449 - lr: 2.5000e-04
# Epoch 57/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0666 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.2333 - val_sparse_categorical_accuracy: 0.9464 - lr: 2.5000e-04
# Epoch 58/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0654 - sparse_categorical_accuracy: 0.9770 - val_loss: 0.2302 - val_sparse_categorical_accuracy: 0.9406 - lr: 2.5000e-04
# Epoch 59/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0636 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.2331 - val_sparse_categorical_accuracy: 0.9408 - lr: 2.5000e-04
# Epoch 60/500
# 693/693 [==============================] - 3s 5ms/step - loss: 0.0638 - sparse_categorical_accuracy: 0.9772 - val_loss: 0.2331 - val_sparse_categorical_accuracy: 0.9440 - lr: 2.5000e-04
# Epoch 60: early stopping

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 371/371 [==============================] - 1s 2ms/step - loss: 0.1415 - sparse_categorical_accuracy: 0.9559
# Test accuracy 0.9559245109558105
# Test loss 0.14151933789253235
